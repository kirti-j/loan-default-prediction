# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
df=pd.read_csv(r"C:\Users\Kirti\OneDrive\Desktop\Loan Default Prediction\data\processed\cleaned_loan_data.csv")

# %%
df.head()
# Out:
#    age  gender marital_status education_level  annual_income  monthly_income  \
# 0   59    male        married        master's       24240.19         2020.02
# 1   72  female        married      bachelor's       20172.98         1681.08
# 2   49  female         single     high school       26181.80         2181.82
# 3   35  female         single     high school       11873.84          989.49
# 4   63   other         single           other       25326.44         2110.54
#
#   employment_status  debt_to_income_ratio  credit_score  loan_amount  ...  \
# 0          employed                 0.074           743     17173.72  ...
# 1          employed                 0.219           531     22663.89  ...
# 2          employed                 0.234           779      3631.36  ...
# 3          employed                 0.264           809     14939.23  ...
# 4          employed                 0.260           663     16551.71  ...
#
# ...

# %%
df.shape
# Out:
# (20000, 22)

# %%
df.describe()
# Out:
#                 age  annual_income  monthly_income  debt_to_income_ratio  \
# count  20000.000000   20000.000000    20000.000000          20000.000000
# mean      48.027000   43549.637766     3629.136466              0.177019
# std       15.829352   28668.579671     2389.048326              0.105059
# min       21.000000    6000.000000      500.000000              0.010000
# 25%       35.000000   24260.752500     2021.730000              0.096000
# 50%       48.000000   36585.260000     3048.770000              0.160000
# 75%       62.000000   54677.917500     4556.495000              0.241000
# max       75.000000  400000.000000    33333.330000              0.667000
#
#        credit_score   loan_amount  interest_rate    loan_term   installment  \
# count   20000.00000  20000.000000   20000.000000  20000.00000  20000.000000
# mean      679.25695  15129.300909      12.400626     43.22280    455.625794
# std        69.63858   8605.405513       2.442729     11.00838    274.622125
# ...

# %%
df.columns
# Out:
# Index(['age', 'gender', 'marital_status', 'education_level', 'annual_income',
#        'monthly_income', 'employment_status', 'debt_to_income_ratio',
#        'credit_score', 'loan_amount', 'loan_purpose', 'interest_rate',
#        'loan_term', 'installment', 'grade_subgrade', 'num_of_open_accounts',
#        'total_credit_limit', 'current_balance', 'delinquency_history',
#        'public_records', 'num_of_delinquencies', 'loan_paid_back'],
#       dtype='object')

# %%
df['loan_status_label']=df['loan_paid_back'].map({0:'Default',1:'Paid'})

# %%
sns.countplot(x="loan_status_label",data=df)
plt.xlabel("loan status label")
plt.title("Loan Paid Back Vs Default")
plt.show()

# %%
df['loan_status_label'].value_counts(normalize=True)*100
# Out:
# loan_status_label
# Paid       79.99
# Default    20.01
# Name: proportion, dtype: float64

# %%
sns.countplot(x='loan_status_label',data=df,hue='gender')
plt.title("Loan Paid Vs Default By Gender")
plt.xlabel("loan status label")
plt.show()

# %%
num_cols=df.select_dtypes(include=np.number).columns
df[num_cols].hist(figsize=(12,10),bins=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# Loan Amount By Age

# %%
sns.countplot(data=df,x='num_of_delinquencies',hue='loan_status_label')
plt.xlabel("number of delinquencies")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.select_dtypes(include='number').corr(),annot=True,cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Numerical Feature Analysis

# %%
num_cols=df.select_dtypes(include=np.number).columns
num_cols
# Out:
# Index(['age', 'annual_income', 'monthly_income', 'debt_to_income_ratio',
#        'credit_score', 'loan_amount', 'interest_rate', 'loan_term',
#        'installment', 'num_of_open_accounts', 'total_credit_limit',
#        'current_balance', 'delinquency_history', 'public_records',
#        'num_of_delinquencies', 'loan_paid_back'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
for col in num_cols:
    plt.figure() 
    sns.histplot(df[col],kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()

# %% [markdown]
# Categorical Feature Analysis

# %%
cat_cols=df.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['gender', 'marital_status', 'education_level', 'employment_status',
#        'loan_purpose', 'grade_subgrade', 'loan_status_label'],
#       dtype='object')

# %%
for col in cat_cols: 
    plt.figure(figsize=(10,5))
    sns.countplot(x=col,data=df)
    plt.title(f"{col} Distribution")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# Numerical Vs Target

# %%
for col in num_cols: 
    if col!='loan_paid_back':
        plt.figure()
        sns.boxplot(x='loan_paid_back',y=col,data=df)
        plt.title(f"{col} Vs Loan Status")
        plt.show()

# %%
for col in cat_cols:
    plt.figure()
    sns.countplot(x=col,hue='loan_paid_back',data=df)
    plt.title(f"{col} vs Loan Status")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# Outlier Detection

# %%
for col in num_cols: 
    plt.figure()
    sns.boxplot(x=df[col])
    plt.title(f"Outliers in {col}")
    plt.show()
